# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import linregress
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from scipy.stats import linregress
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# Load the data
df = pd.read_csv("assets/epa-sea-level.csv")
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %% [markdown]
# Use matplotlib to create a scatter plot using the Year column as the x-axis and the CSIRO Adjusted Sea Level column as the y-axis.

# %%
# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], color='b', label='Sea Level')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('CSIRO Adjusted Sea Level (inches)')
plt.title('Sea Level Rise')

# Show plot
plt.legend()
plt.show()

# %% [markdown]
# Use the linregress function from scipy.stats to get the slope and y-intercept of the line of best fit. Plot the line of best fit over the top of the scatter plot. Make the line go through the year 2050 to predict the sea level rise in 2050.

# %%
# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], color='b', label='Sea Level')

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])

# Create an array of years from the start year to 2050
years = np.arange(df['Year'].min(), 2051)

# Calculate the corresponding sea levels using the slope and intercept
sea_levels = intercept + slope * years

# Plot the line of best fit
plt.plot(years, sea_levels, color='r', label='Best Fit Line')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('CSIRO Adjusted Sea Level (inches)')
plt.title('Sea Level Rise')
plt.legend()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       3 plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], color='b', label='Sea Level')
#       5 # Perform linear regression
# ----> 6 slope, intercept, r_value, p_value, std_err = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
#       8 # Create an array of years from the start year to 2050
#       9 years = np.arange(df['Year'].min(), 2051)
#
# NameError: name 'linregress' is not defined
